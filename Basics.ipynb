# %% [markdown]
# # Ebay Car Sales Data Analyses

# %% [markdown]
# We will clean and analyse car sales data.

# %% [markdown]
# * dateCrawled - When this ad was first crawled. All field-values are taken from this date.
# * name - Name of the car.
# * seller - Whether the seller is private or a dealer.
# * offerType - The type of listing
# * price - The price on the ad to sell the car.
# * abtest - Whether the listing is included in an A/B test.
# * vehicleType - The vehicle Type.
# * yearOfRegistration - The year in which the car was first registered.
# * gearbox - The transmission type.
# * powerPS - The power of the car in PS.
# * model - The car model name.
# * kilometer - How many kilometers the car has driven.
# * monthOfRegistration - The month in which the car was first registered.
# * fuelType - What type of fuel the car uses.
# * brand - The brand of the car.
# * notRepairedDamage - If the car has a damage which is not yet repaired.
# * dateCreated - The date on which the eBay listing was created.
# * nrOfPictures - The number of pictures in the ad.
# * postalCode - The postal code for the location of the vehicle.
# * lastSeenOnline - When the crawler saw this ad last online.

# %%
import numpy as np
import pandas as pd

# %%
autos = pd.read_csv("autos.csv", encoding="Latin-1")

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# postalCode             50000 non-null int64
# lastSeen               50000 non-null object
# dtypes: int64(5), object(15)
# memory usage: 7.6+ MB

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# 0    manuell      158  andere  150,000km                    3      lpg
# 1  automatik      286     7er  150,000km                    6   benzin
# 2    manuell      102    golf   70,000km                    7   benzin
# 3  automatik       71  fortwo   70,000km                    6   benzin
# 4    manuell        0   focus  150,000km                    7   benzin
#
#         brand notRepairedDamage          dateCreated  nrOfPictures  \
# 0     peugeot              nein  2016-03-26 00:00:00             0
# 1         bmw              nein  2016-04-04 00:00:00             0
# 2  volkswagen              nein  2016-03-26 00:00:00             0
# 3       smart              nein  2016-03-12 00:00:00             0
# 4        ford              nein  2016-04-01 00:00:00             0
#
#    postalCode             lastSeen
# 0       79588  2016-04-06 06:45:54
# 1       71034  2016-04-06 14:45:08
# 2       35394  2016-04-06 20:15:37
# 3       33729  2016-03-15 03:16:28
# 4       39218  2016-04-01 14:38:50

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest','vehicle_type', 'registration_year', 'gearbox', 'powerPS', 'model','odometer', 'registration_month', 'fuel_type', 'brand','unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code','last_seen']

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  powerPS   model   odometer  registration_month fuel_type  \
# 0    manuell      158  andere  150,000km                   3       lpg
# 1  automatik      286     7er  150,000km                   6    benzin
# 2    manuell      102    golf   70,000km                   7    benzin
# 3  automatik       71  fortwo   70,000km                   6    benzin
# 4    manuell        0   focus  150,000km                   7    benzin
#
#         brand unrepaired_damage           ad_created  nr_of_pictures  \
# 0     peugeot              nein  2016-03-26 00:00:00               0
# 1         bmw              nein  2016-04-04 00:00:00               0
# 2  volkswagen              nein  2016-03-26 00:00:00               0
# 3       smart              nein  2016-03-12 00:00:00               0
# 4        ford              nein  2016-04-01 00:00:00               0
#
#    postal_code            last_seen
# 0        79588  2016-04-06 06:45:54
# 1        71034  2016-04-06 14:45:08
# 2        35394  2016-04-06 20:15:37
# 3        33729  2016-03-15 03:16:28
# 4        39218  2016-04-01 14:38:50

# %% [markdown]
# Changed the column names from camelCase to snake_case as it is prefered by python.

# %%
autos.describe(include="all")
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-10 15:36:24  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox       powerPS  model  \
# count         44905       50000.000000    47320  50000.000000  47242
# unique            8                NaN        2           NaN    245
# top       limousine                NaN  manuell           NaN   golf
# freq          12859                NaN    36993           NaN   4024
# mean            NaN        2005.073280      NaN    116.355920    NaN
# std             NaN         105.712813      NaN    209.216627    NaN
# min             NaN        1000.000000      NaN      0.000000    NaN
# 25%             NaN        1999.000000      NaN     70.000000    NaN
# 50%             NaN        2003.000000      NaN    105.000000    NaN
# 75%             NaN        2008.000000      NaN    150.000000    NaN
# max             NaN        9999.000000      NaN  17700.000000    NaN
#
#          odometer  registration_month fuel_type       brand unrepaired_damage  \
# count       50000        50000.000000     45518       50000             40171
# unique         13                 NaN         7          40                 2
# top     150,000km                 NaN    benzin  volkswagen              nein
# freq        32424                 NaN     30107       10687             35232
# mean          NaN            5.723360       NaN         NaN               NaN
# std           NaN            3.711984       NaN         NaN               NaN
# min           NaN            0.000000       NaN         NaN               NaN
# 25%           NaN            3.000000       NaN         NaN               NaN
# 50%           NaN            6.000000       NaN         NaN               NaN
# 75%           NaN            9.000000       NaN         NaN               NaN
# max           NaN           12.000000       NaN         NaN               NaN
#
#                  ad_created  nr_of_pictures   postal_code            last_seen
# count                 50000         50000.0  50000.000000                50000
# unique                   76             NaN           NaN                39481
# top     2016-04-03 00:00:00             NaN           NaN  2016-04-07 06:17:27
# freq                   1946             NaN           NaN                    8
# mean                    NaN             0.0  50813.627300                  NaN
# std                     NaN             0.0  25779.747957                  NaN
# min                     NaN             0.0   1067.000000                  NaN
# 25%                     NaN             0.0  30451.000000                  NaN
# 50%                     NaN             0.0  49577.000000                  NaN
# 75%                     NaN             0.0  71540.000000                  NaN
# max                     NaN             0.0  99998.000000                  NaN

# %%
autos['seller'].value_counts()
# Out:
# privat        49999
# gewerblich        1
# Name: seller, dtype: int64

# %%
autos['offer_type'].value_counts()
# Out:
# Angebot    49999
# Gesuch         1
# Name: offer_type, dtype: int64

# %% [markdown]
# * seller column has 49999 - private | 1 - commercial(gewerblich)
# * offer_type has 49999 - Angebot | 1 - Gesuch
# * odometer and price column needs to be cleaned and converted to int/float

# %%
autos[['odometer', 'price']].head()
# Out:
#     odometer   price
# 0  150,000km  $5,000
# 1  150,000km  $8,500
# 2   70,000km  $8,990
# 3   70,000km  $4,350
# 4  150,000km  $1,350

# %%
autos['price'].isnull().sum()
# Out:
# 0

# %%
autos['odometer'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No null value is present in odometer and price column

# %%
autos['odometer'] = autos['odometer'].str.replace("km", "")
autos['odometer'] = autos['odometer'].str.replace(",", "")

# %%
autos['odometer'] = autos['odometer'].astype(int)

# %%
autos['price'] = autos['price'].str.replace("$", "")
autos['price'] = autos['price'].str.replace(",", "")

# %%
autos['price'] = autos['price'].astype(int)

# %% [markdown]
# Changed the odometer and price column to int type

# %%
autos.rename({"odometer":"odometer_km"}, inplace = True, axis = 1)

# %% [markdown]
# Renamed the odometer column to odometer_km to show units

# %% [markdown]
# ***Closer look on odometer and price column***

# %%
autos['odometer_km'].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos['price'].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
np.sum(autos["price"] == 0)
# Out:
# 1421

# %%
autos[autos['price'] == autos['price'].max()]
# Out:
#               date_crawled                         name  seller offer_type  \
# 39705  2016-03-22 14:58:27  Tausch_gegen_gleichwertiges  privat    Angebot
#
#           price   abtest vehicle_type  registration_year    gearbox  powerPS  \
# 39705  99999999  control    limousine               1999  automatik      224
#
#           model  odometer_km  registration_month fuel_type          brand  \
# 39705  s_klasse       150000                   9    benzin  mercedes_benz
#
#       unrepaired_damage           ad_created  nr_of_pictures  postal_code  \
# 39705               NaN  2016-03-22 00:00:00               0        73525
#
#                  last_seen
# 39705  2016-04-06 05:15:30

# %%
autos['price'].sort_values(ascending=False)
# Out:
# 39705    99999999
# 42221    27322222
# 39377    12345678
# 47598    12345678
# 27371    12345678
# 2897     11111111
# 24384    11111111
# 11137    10000000
# 47634     3890000
# 7814      1300000
# 22947     1234566
# 43049      999999
# 514        999999
# 37585      999990
# 36818      350000
# 14715      345000
# 34723      299000
# 35923      295000
# 12682      265000
# 47337      259000
# 38299      250000
# 37840      220000
# 40918      198000
# 43668      197000
# 28090      194000
# 20351      190000
# 17140      180000
# 11433      175000
# 32840      169999
# 18509      169000
#            ...
# 21171           0
# 24900           0
# 1220            0
# 31264           0
# 24871           0
# 2470            0
# 21256           0
# 29503           0
# 37021           0
# 21253           0
# 47861           0
# 29482           0
# 31336           0
# 35819           0
# 27020           0
# 4266            0
# 2481            0
# 15208           0
# 33620           0
# 12819           0
# 31332           0
# 35821           0
# 8438            0
# 43925           0
# 38832           0
# 8445            0
# 29499           0
# 15225           0
# 43923           0
# 18089           0
# Name: price, Length: 50000, dtype: int64

# %%
acceptable = (autos['price']<1000) | (autos['price']>=4800000)

# %%
autos[acceptable].size
# Out:
# 227360

# %%
autos.drop(autos[acceptable].index, axis=0, inplace=True)

# %%
autos['price'].describe()
# Out:
# count    3.863200e+04
# mean     7.498207e+03
# std      2.535787e+04
# min      1.000000e+03
# 25%      2.200000e+03
# 50%      4.350000e+03
# 75%      8.950000e+03
# max      3.890000e+06
# Name: price, dtype: float64

# %% [markdown]
# Removed the ad listing within price below 1000 and above and equal to 4800000 (price of most expensive car as per 2016) because the price listed was unreal/too high or too low.

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type  price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot   5000  control          bus               2004
# 1  privat    Angebot   8500  control    limousine               1997
# 2  privat    Angebot   8990     test    limousine               2009
# 3  privat    Angebot   4350  control   kleinwagen               2007
# 4  privat    Angebot   1350     test        kombi               2003
#
#      gearbox  powerPS   model  odometer_km  registration_month fuel_type  \
# 0    manuell      158  andere       150000                   3       lpg
# 1  automatik      286     7er       150000                   6    benzin
# 2    manuell      102    golf        70000                   7    benzin
# 3  automatik       71  fortwo        70000                   6    benzin
# 4    manuell        0   focus       150000                   7    benzin
#
#         brand unrepaired_damage           ad_created  nr_of_pictures  \
# 0     peugeot              nein  2016-03-26 00:00:00               0
# 1         bmw              nein  2016-04-04 00:00:00               0
# 2  volkswagen              nein  2016-03-26 00:00:00               0
# 3       smart              nein  2016-03-12 00:00:00               0
# 4        ford              nein  2016-04-01 00:00:00               0
#
#    postal_code            last_seen
# 0        79588  2016-04-06 06:45:54
# 1        71034  2016-04-06 14:45:08
# 2        35394  2016-04-06 20:15:37
# 3        33729  2016-03-15 03:16:28
# 4        39218  2016-04-01 14:38:50

# %%
autos[['date_crawled', 'ad_created', 'last_seen']].head()
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
autos['date_crawled'].str[:10].sort_index().head()
# Out:
# 0    2016-03-26
# 1    2016-04-04
# 2    2016-03-26
# 3    2016-03-12
# 4    2016-04-01
# Name: date_crawled, dtype: object

# %%
autos['date_crawled'].str[8:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 01    0.034609
# 02    0.036291
# 03    0.039139
# 04    0.036912
# 05    0.038906
# 06    0.017136
# 07    0.036628
# 08    0.032615
# 09    0.032460
# 10    0.033314
# 11    0.032797
# 12    0.037378
# 13    0.015997
# 14    0.036628
# 15    0.033625
# 16    0.029069
# 17    0.030493
# 18    0.012839
# 19    0.035126
# 20    0.038155
# 21    0.037301
# 22    0.032538
# 23    0.032201
# 24    0.029017
# 25    0.030519
# 26    0.033107
# 27    0.031399
# 28    0.035359
# 29    0.033987
# 30    0.033055
# 31    0.031399
# Name: date_crawled, dtype: float64

# %%
autos['ad_created'].str[8:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 01    0.034583
# 02    0.036136
# 03    0.040329
# 04    0.038854
# 05    0.035075
# 06    0.018508
# 07    0.035178
# 08    0.032564
# 09    0.032693
# 10    0.033081
# 11    0.033107
# 12    0.037171
# 13    0.017680
# 14    0.035049
# 15    0.033444
# 16    0.029690
# 17    0.030208
# 18    0.013331
# 19    0.034143
# 20    0.038284
# 21    0.037637
# 22    0.032382
# 23    0.032046
# 24    0.029069
# 25    0.030752
# 26    0.033237
# 27    0.031451
# 28    0.035644
# 29    0.034194
# 30    0.032926
# 31    0.031554
# Name: ad_created, dtype: float64

# %%
autos['last_seen'].str[8:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 01    0.023193
# 02    0.024928
# 03    0.024436
# 04    0.023374
# 05    0.132248
# 06    0.238248
# 07    0.144517
# 08    0.006238
# 09    0.008905
# 10    0.009811
# 11    0.011726
# 12    0.022184
# 13    0.008387
# 14    0.011985
# 15    0.014988
# 16    0.015454
# 17    0.026377
# 18    0.007377
# 19    0.014599
# 20    0.019802
# 21    0.019673
# 22    0.020786
# 23    0.017913
# 24    0.018534
# 25    0.017757
# 26    0.016075
# 27    0.014082
# 28    0.019440
# 29    0.020786
# 30    0.023452
# 31    0.022727
# Name: last_seen, dtype: float64

# %%
autos['registration_year'].describe()
# Out:
# count    38632.000000
# mean      2005.678194
# std         86.678597
# min       1000.000000
# 25%       2001.000000
# 50%       2005.000000
# 75%       2009.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %%
autos['registration_year'].sort_values()
# Out:
# 22316    1000
# 49283    1001
# 21416    1927
# 22101    1929
# 11246    1931
# 2221     1934
# 2573     1934
# 39725    1937
# 21421    1937
# 23804    1937
# 26607    1937
# 26103    1938
# 24855    1939
# 13963    1941
# 25792    1941
# 11585    1943
# 11047    1948
# 14020    1950
# 35921    1951
# 44406    1951
# 23372    1952
# 35453    1953
# 40765    1954
# 25556    1954
# 24515    1955
# 36794    1955
# 7294     1956
# 26570    1956
# 23483    1956
# 19914    1956
#          ...
# 34111    2018
# 7137     2018
# 43577    2018
# 5164     2018
# 25799    2018
# 41042    2018
# 19373    2018
# 46986    2018
# 43589    2018
# 48065    2018
# 41084    2018
# 33999    2018
# 3848     2018
# 34099    2018
# 41111    2018
# 34107    2018
# 41045    2018
# 47016    2018
# 49185    2019
# 27578    2800
# 4549     4100
# 453      4500
# 22799    5000
# 49153    5000
# 27618    5911
# 8360     6200
# 25003    8888
# 49910    9000
# 33950    9999
# 38076    9999
# Name: registration_year, Length: 38632, dtype: int64

# %%
autos[autos['registration_year'] == 2016]
# Out:
#               date_crawled                                               name  \
# 76     2016-03-22 14:52:57                         BMW_318i_neustes_Model_0Km
# 135    2016-03-12 11:00:10  Opel_Meriva_B_Panoramadach__Sitz__und_Lenkradh...
# 256    2016-04-03 20:50:38                     Passat_1.9TDI_4Motion_Highline
# 295    2016-03-28 03:36:22                                     Privat_anbiter
# 307    2016-03-15 22:50:48                                       Giessen_ford
# 374    2016-03-15 18:42:52                          Polo_9N_1_9_Tdi_Gti_Optik
# 479    2016-03-08 07:55:41                              Renault_R4_TL_Savanne
# 495    2016-03-17 18:45:02                                       BMW_1er_116i
# 507    2016-03-08 13:45:53                                      Citroën_Xsara
# 520    2016-03-07 00:52:52               Gut_gepflegter_Golf_GTI_zu_verkaufen
# 574    2016-03-27 18:39:33                                   VW_vento_2_8_vr6
# 696    2016-03-08 03:55:14                           Audi_a6_avant_2.5_tdi_v6
# 1021   2016-03-25 08:57:19                     BMW_316i_Leder_Voll_FAHRBETEIT
# 1133   2016-03-14 16:47:42                 Fiat_Panda_HP_100_Klimaautomatic!!
# 1153   2016-03-17 23:53:33                    Audi_A3_Sportback_2.0TDI_S_Line
# 1306   2016-04-01 20:37:43           Peugeot_607_HDI_2.2_mit_gruener_Plakette
# 1326   2016-03-21 19:47:32          Opel_Meriva_A_in_einem_gepflegten_Zustand
# 1474   2016-04-01 22:37:14         Golf_Vr6_Turbo_HGP_Turbo_Alles_Eingetragen
# 1555   2016-03-17 01:00:21  Audi_Cabriolet____A5___NAVI_.XEN_._ALCANTARA.S...
# 1562   2016-03-19 20:54:16  RENAULT_TWINGO___ERST_3_MONATE_ALT_UND_2000_KM...
# 1593   2016-03-27 19:50:57                         BMW_520I_AUTOMATIKGETRIEBE
# 1632   2016-03-29 23:48:06                                 Fiat_Idea_Mini_Van
# 1741   2016-03-24 23:57:44                           Vw_Golf_4_2.0__121000_km
# 1866   2016-03-07 17:42:12  MICROCAR_M.GO_Dynamic_Mopedauto_Leichtkraftfah...
# 1956   2016-03-07 15:46:32                          Volkswagen_Passat_1_9_tdi
# 1988   2016-03-17 20:36:21                      Polo_9n3_1.6l_105PS_Automatik
# 2278   2016-03-15 18:53:59                           Bmw_318_Coupe_M_Original
# 2280   2016-03-31 17:51:37                                        Ford_fiesta
# 2446   2016-03-24 22:51:23                                    Golf_5__TDI_1.9
# 2534   2016-03-07 09:57:07                                      Golf_1_Cabrio
# ...                    ...                                                ...
# 47848  2016-03-10 18:43:09       Alfa_romeo_zu_verkaufen_Liebhaber_Auto____:_
# 47850  2016-03-26 22:37:33                               verkaufe_skoda_fabia
# 47935  2016-03-08 10:38:12                            Bmw_e39_in_guten_zutant
# 47982  2016-04-04 22:46:28                  Renault_Espace_2.0_136_PS_1998ccm
# 48021  2016-03-20 22:52:25                           Golf_4_1_4_tuev_bis_6/16
# 48058  2016-04-03 18:56:46  BMW_120D_Coupe_NAVI/_KEYLESS/LEDER/_TEMPOMAT/_PDC
# 48062  2016-03-27 14:46:50                               Fiat_Scudo_1_6benzin
# 48082  2016-04-01 21:55:53             Audi_A6_Avant_2.5_TDI_BJ_2003_Facelift
# 48198  2016-04-04 11:57:12                            VW_Passat_3bg_tdi_131ps
# 48254  2016-03-17 15:51:12                                  Ford_Focus_2_Tdci
# 48275  2016-03-08 19:37:00                           FIAT_PUNTO_188_..._60_PS
# 48317  2016-03-06 02:36:25  e36_325i_coupe_neulack_bilder_folgen_bbs_rf_st...
# 48464  2016-03-17 15:37:39                 A_Klasse_170_CDI_Klima_sitzheizung
# 48514  2016-03-28 20:49:59       Renault_Senic_Megane_16V_nur_34500km_TÜV_neu
# 48752  2016-03-05 15:49:03               Opel_Astra_1_4T_MAHAGONIBRAUN_1.HAND
# 48768  2016-04-03 18:54:34                       Golf_4_mit_Anhaengerkupplung
# 48828  2016-03-24 22:51:18  Grand_Cherokee_ZJ__5_2l__neue_Stossdaempfer__a...
# 48866  2016-03-17 09:51:16                              Opel_vectra_B_1_8_16v
# 48893  2016-03-27 00:57:38                                         Polo_Kombi
# 48923  2016-03-21 15:55:27                               Suche_ein_golf_4_1.6
# 49189  2016-03-24 17:37:23                 Skoda_Fabia_Combi_1.2_TSI_Ambition
# 49195  2016-03-18 21:41:55             Golf_IV_Generation__1_4l__55_kw__Klima
# 49239  2016-03-05 14:51:22                   Audi_Coupe_typ_89_quattro_2_6_s2
# 49258  2016-04-03 20:42:15             BMW_e36_328i_Cabrio_!!!Neu_lackiert!!!
# 49324  2016-04-01 16:36:34  Mercedes_Benz_Vito_111_BlueTEC_Tourer_Kompakt_PRO
# 49340  2016-03-05 19:52:28  Nagelneuer_Adam__viele_Extras__aus_Gewinn._NIE...
# 49547  2016-03-30 16:49:46                    Smart_Passion_mit_Panorama_Dach
# 49852  2016-04-01 04:02:25                                   TOP__Golf_3_1.8l
# 49876  2016-03-22 17:57:24                             Audi_a5_3.0_tdi_s_line
# 49938  2016-03-28 18:45:06                     Mercedes_Benz_A_160_Avantgarde
#
#        seller offer_type  price   abtest vehicle_type  registration_year  \
# 76     privat    Angebot  31999  control    limousine               2016
# 135    privat    Angebot   8500  control          NaN               2016
# 256    privat    Angebot   4250     test          NaN               2016
# 295    privat    Angebot   1000  control          NaN               2016
# 307    privat    Angebot   2800     test          NaN               2016
# 374    privat    Angebot   3850  control          NaN               2016
# 479    privat    Angebot   6450     test          NaN               2016
# 495    privat    Angebot   8000  control          NaN               2016
# 507    privat    Angebot   1250  control          NaN               2016
# 520    privat    Angebot   6600     test          NaN               2016
# 574    privat    Angebot  10000  control          NaN               2016
# 696    privat    Angebot   2500  control          NaN               2016
# 1021   privat    Angebot   1699  control          NaN               2016
# 1133   privat    Angebot   4790     test          NaN               2016
# 1153   privat    Angebot   8000  control          NaN               2016
# 1306   privat    Angebot   2199     test          NaN               2016
# 1326   privat    Angebot   2450     test          NaN               2016
# 1474   privat    Angebot   9500     test          NaN               2016
# 1555   privat    Angebot  37450     test       cabrio               2016
# 1562   privat    Angebot   6900  control   kleinwagen               2016
# 1593   privat    Angebot   2800     test          NaN               2016
# 1632   privat    Angebot   1990  control          NaN               2016
# 1741   privat    Angebot   1650     test          NaN               2016
# 1866   privat    Angebot  11000     test   kleinwagen               2016
# 1956   privat    Angebot   2700  control          NaN               2016
# 1988   privat    Angebot   6500  control          NaN               2016
# 2278   privat    Angebot   2600  control          NaN               2016
# 2280   privat    Angebot   2350  control          NaN               2016
# 2446   privat    Angebot   3500  control          NaN               2016
# 2534   privat    Angebot   1900  control          NaN               2016
# ...       ...        ...    ...      ...          ...                ...
# 47848  privat    Angebot   1500     test          NaN               2016
# 47850  privat    Angebot   5000     test          NaN               2016
# 47935  privat    Angebot   1850     test          NaN               2016
# 47982  privat    Angebot   3800     test          NaN               2016
# 48021  privat    Angebot   1200     test          NaN               2016
# 48058  privat    Angebot  11999  control          NaN               2016
# 48062  privat    Angebot   2600  control          NaN               2016
# 48082  privat    Angebot   1350     test          NaN               2016
# 48198  privat    Angebot   1400  control          NaN               2016
# 48254  privat    Angebot   6500     test          NaN               2016
# 48275  privat    Angebot   1800     test          NaN               2016
# 48317  privat    Angebot   7999  control          NaN               2016
# 48464  privat    Angebot   1250     test          NaN               2016
# 48514  privat    Angebot   2999  control          NaN               2016
# 48752  privat    Angebot   8850  control          NaN               2016
# 48768  privat    Angebot   1150  control          NaN               2016
# 48828  privat    Angebot   2200  control          NaN               2016
# 48866  privat    Angebot   1650     test          NaN               2016
# 48893  privat    Angebot   1750     test          NaN               2016
# 48923  privat    Angebot   1000  control          NaN               2016
# 49189  privat    Angebot  11995  control        kombi               2016
# 49195  privat    Angebot   2200  control          NaN               2016
# 49239  privat    Angebot   1500  control          NaN               2016
# 49258  privat    Angebot   5000     test          NaN               2016
# 49324  privat    Angebot  29500  control        kombi               2016
# 49340  privat    Angebot  12990     test   kleinwagen               2016
# 49547  privat    Angebot   3600     test          NaN               2016
# 49852  privat    Angebot   1450  control          NaN               2016
# 49876  privat    Angebot  14700  control          NaN               2016
# 49938  privat    Angebot   2300  control          NaN               2016
#
#          gearbox  powerPS     model  odometer_km  registration_month  \
# 76       manuell      136       3er         5000                   2
# 135      manuell       81    meriva        90000                   8
# 256      manuell      131    passat       150000                  11
# 295      manuell        0     astra       150000                   8
# 307      manuell      109     focus       150000                   8
# 374      manuell      101      polo       150000                   0
# 479          NaN        0    andere        70000                   0
# 495      manuell      122       1er        80000                  12
# 507      manuell      109       NaN       150000                   7
# 520      manuell      200      golf       150000                   4
# 574      manuell      174    andere       150000                   5
# 696          NaN        0        a6        40000                   3
# 1021     manuell      101       1er       150000                   6
# 1133     manuell      101     panda        80000                   0
# 1153     manuell      140        a3       150000                   5
# 1306   automatik      133       NaN       150000                   0
# 1326     manuell        0    meriva       150000                  11
# 1474     manuell      330      golf       150000                   5
# 1555     manuell      177    andere         5000                   3
# 1562     manuell       71    twingo         5000                   1
# 1593   automatik      170       5er       150000                   6
# 1632     manuell       80    andere       150000                   2
# 1741     manuell      116       NaN       125000                   8
# 1866   automatik        5       NaN         5000                   3
# 1956         NaN      101    passat         5000                   0
# 1988   automatik      105      polo       125000                   0
# 2278   automatik        0       3er       150000                   0
# 2280     manuell       60       NaN       150000                   3
# 2446     manuell      105      golf       150000                   8
# 2534     manuell       98      golf       150000                   1
# ...          ...      ...       ...          ...                 ...
# 47848    manuell      115       NaN       150000                   6
# 47850  automatik       75     fabia        30000                  10
# 47935    manuell        0       5er       150000                   4
# 47982    manuell        0    espace       150000                   6
# 48021    manuell       72      golf       150000                   5
# 48058    manuell      177       1er       150000                   5
# 48062    manuell        0       NaN       100000                   8
# 48082  automatik      163        a6       150000                   4
# 48198        NaN        0    passat       150000                  12
# 48254    manuell      136     focus        90000                   3
# 48275    manuell       60     punto       125000                   1
# 48317    manuell      220       3er       150000                   6
# 48464        NaN        0  a_klasse       150000                   8
# 48514    manuell      116       NaN        40000                   8
# 48752    manuell      140       NaN        60000                  10
# 48768    manuell       75      golf       150000                   2
# 48828        NaN      211       NaN       150000                   6
# 48866    manuell        0    vectra       150000                   5
# 48893    manuell       75      polo       150000                   6
# 48923    manuell        0      golf       150000                   0
# 49189    manuell       90     fabia         5000                   3
# 49195    manuell       75      golf       125000                   9
# 49239    manuell      150       NaN       150000                  12
# 49258    manuell      193       NaN       150000                   5
# 49324    manuell      114      vito         5000                   2
# 49340    manuell       87    andere         5000                   3
# 49547        NaN       71    fortwo       125000                  10
# 49852        NaN       75      golf       150000                   7
# 49876    manuell        0       NaN       150000                  10
# 49938  automatik      102  a_klasse       150000                   6
#
#       fuel_type           brand unrepaired_damage           ad_created  \
# 76       benzin             bmw               NaN  2016-03-22 00:00:00
# 135      diesel            opel               NaN  2016-03-12 00:00:00
# 256         NaN      volkswagen               NaN  2016-04-03 00:00:00
# 295      benzin            opel               NaN  2016-03-28 00:00:00
# 307         NaN            ford               NaN  2016-03-15 00:00:00
# 374      diesel      volkswagen               NaN  2016-03-15 00:00:00
# 479         NaN         renault               NaN  2016-03-08 00:00:00
# 495      benzin             bmw              nein  2016-03-17 00:00:00
# 507      benzin         citroen              nein  2016-03-08 00:00:00
# 520      benzin      volkswagen               NaN  2016-03-06 00:00:00
# 574         NaN      volkswagen              nein  2016-03-27 00:00:00
# 696      diesel            audi              nein  2016-03-08 00:00:00
# 1021     benzin             bmw               NaN  2016-03-25 00:00:00
# 1133        NaN            fiat               NaN  2016-03-14 00:00:00
# 1153        NaN            audi              nein  2016-03-17 00:00:00
# 1306     diesel         peugeot               NaN  2016-04-01 00:00:00
# 1326        lpg            opel              nein  2016-03-21 00:00:00
# 1474        NaN      volkswagen              nein  2016-04-01 00:00:00
# 1555     benzin            audi              nein  2016-03-17 00:00:00
# 1562     benzin         renault               NaN  2016-03-19 00:00:00
# 1593        NaN             bmw               NaN  2016-03-27 00:00:00
# 1632        NaN            fiat              nein  2016-03-29 00:00:00
# 1741     benzin      volkswagen               NaN  2016-03-24 00:00:00
# 1866     diesel  sonstige_autos              nein  2016-03-07 00:00:00
# 1956     diesel      volkswagen              nein  2016-03-07 00:00:00
# 1988     benzin      volkswagen               NaN  2016-03-17 00:00:00
# 2278     benzin             bmw              nein  2016-03-15 00:00:00
# 2280        NaN            ford               NaN  2016-03-31 00:00:00
# 2446        NaN      volkswagen              nein  2016-03-24 00:00:00
# 2534        NaN      volkswagen               NaN  2016-03-07 00:00:00
# ...         ...             ...               ...                  ...
# 47848       NaN      alfa_romeo               NaN  2016-03-10 00:00:00
# 47850       NaN           skoda              nein  2016-03-26 00:00:00
# 47935    benzin             bmw              nein  2016-03-08 00:00:00
# 47982    benzin         renault              nein  2016-04-04 00:00:00
# 48021       NaN      volkswagen              nein  2016-03-20 00:00:00
# 48058    diesel             bmw              nein  2016-04-03 00:00:00
# 48062       NaN            fiat              nein  2016-03-27 00:00:00
# 48082       NaN            audi                ja  2016-04-01 00:00:00
# 48198    diesel      volkswagen               NaN  2016-04-04 00:00:00
# 48254    diesel            ford              nein  2016-03-17 00:00:00
# 48275       NaN            fiat              nein  2016-03-08 00:00:00
# 48317       NaN             bmw              nein  2016-03-06 00:00:00
# 48464    diesel   mercedes_benz               NaN  2016-03-17 00:00:00
# 48514    benzin         renault               NaN  2016-03-28 00:00:00
# 48752    benzin            opel               NaN  2016-03-05 00:00:00
# 48768       NaN      volkswagen              nein  2016-04-03 00:00:00
# 48828       lpg            jeep               NaN  2016-03-24 00:00:00
# 48866    benzin            opel              nein  2016-03-17 00:00:00
# 48893       NaN      volkswagen              nein  2016-03-26 00:00:00
# 48923    benzin      volkswagen               NaN  2016-03-21 00:00:00
# 49189    benzin           skoda              nein  2016-03-24 00:00:00
# 49195    benzin      volkswagen              nein  2016-03-18 00:00:00
# 49239       NaN            audi               NaN  2016-03-05 00:00:00
# 49258       NaN             bmw              nein  2016-04-03 00:00:00
# 49324    diesel   mercedes_benz              nein  2016-04-01 00:00:00
# 49340    benzin            opel              nein  2016-03-03 00:00:00
# 49547    benzin           smart               NaN  2016-03-30 00:00:00
# 49852    benzin      volkswagen               NaN  2016-04-01 00:00:00
# 49876    diesel            audi               NaN  2016-03-22 00:00:00
# 49938    benzin   mercedes_benz              nein  2016-03-28 00:00:00
#
#        nr_of_pictures  postal_code            last_seen
# 76                  0        45149  2016-04-06 05:15:42
# 135                 0        48147  2016-03-22 14:49:31
# 256                 0        31224  2016-04-03 20:50:38
# 295                 0        44147  2016-03-29 23:18:11
# 307                 0        35396  2016-04-07 05:16:07
# 374                 0        21762  2016-03-20 15:17:50
# 479                 0        57462  2016-04-06 06:46:24
# 495                 0        34329  2016-04-06 00:46:31
# 507                 0        23883  2016-03-09 12:15:17
# 520                 0        59939  2016-03-12 16:49:44
# 574                 0        36457  2016-04-05 14:47:50
# 696                 0        49577  2016-03-12 22:17:43
# 1021                0        51145  2016-04-04 06:23:02
# 1133                0        94113  2016-03-23 17:16:40
# 1153                0         8248  2016-04-05 21:16:09
# 1306                0        44147  2016-04-03 17:18:48
# 1326                0        94315  2016-03-23 00:47:15
# 1474                0        68309  2016-04-06 00:46:01
# 1555                0        95444  2016-03-17 07:38:03
# 1562                0        41238  2016-03-19 21:42:49
# 1593                0        65933  2016-04-06 01:15:29
# 1632                0        27612  2016-04-06 13:16:55
# 1741                0        56727  2016-03-29 12:16:53
# 1866                0        19288  2016-03-29 19:18:13
# 1956                0        37581  2016-03-29 05:18:08
# 1988                0        37197  2016-03-19 20:47:48
# 2278                0        12049  2016-03-15 18:53:59
# 2280                0        92360  2016-04-06 11:44:27
# 2446                0        81737  2016-03-26 14:44:59
# 2534                0        84048  2016-03-11 10:18:05
# ...               ...          ...                  ...
# 47848               0        57439  2016-03-17 05:44:22
# 47850               0        66123  2016-04-06 23:16:20
# 47935               0        44575  2016-03-12 00:16:31
# 47982               0        96052  2016-04-07 01:44:38
# 48021               0        24848  2016-04-07 12:15:24
# 48058               0        45659  2016-04-05 19:19:29
# 48062               0        21073  2016-04-07 11:16:58
# 48082               0        52525  2016-04-01 22:40:53
# 48198               0        16321  2016-04-04 11:57:12
# 48254               0        39418  2016-03-23 02:15:28
# 48275               0        45149  2016-04-05 13:17:31
# 48317               0        64739  2016-04-06 01:50:10
# 48464               0        89077  2016-03-17 15:37:39
# 48514               0        99974  2016-04-07 03:44:33
# 48752               0         7616  2016-04-05 19:17:27
# 48768               0        13593  2016-04-05 19:19:19
# 48828               0        44892  2016-03-25 02:42:18
# 48866               0        74321  2016-03-21 12:17:08
# 48893               0        51465  2016-04-07 04:16:46
# 48923               0        32120  2016-03-22 20:47:39
# 49189               0        82229  2016-04-07 10:17:21
# 49195               0        21629  2016-03-20 05:47:44
# 49239               0        23847  2016-03-12 18:15:18
# 49258               0        84186  2016-04-05 21:17:08
# 49324               0        35037  2016-04-07 12:44:36
# 49340               0        48249  2016-03-22 19:18:46
# 49547               0        49413  2016-03-30 16:49:46
# 49852               0        67661  2016-04-05 03:17:29
# 49876               0        44227  2016-03-22 18:40:53
# 49938               0        13507  2016-04-07 00:44:35
#
# [651 rows x 20 columns]

# %%
reg_year_range = (autos['registration_year']<1927) | (autos['registration_year']>2016)

# %%
np.sum(reg_year_range)
# Out:
# 1420

# %%
reg_year_range.index
# Out:
# Int64Index([    0,     1,     2,     3,     4,     5,     7,    12,    13,
#                14,
#             ...
#             49988, 49990, 49992, 49993, 49994, 49995, 49996, 49997, 49998,
#             49999],
#            dtype='int64', length=38632)

# %%
autos.drop(autos[reg_year_range].index, axis=0, inplace=True)

# %%
autos['registration_year'].describe()
# Out:
# count    37212.000000
# mean      2003.967618
# std          7.021028
# min       1927.000000
# 25%       2001.000000
# 50%       2005.000000
# 75%       2008.000000
# max       2016.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# Droped the registration year values which were impossibly old or had a registration year of the future which is again impossible.

# %%
(autos['registration_year'].value_counts(normalize=True).sort_index())*100
# multiplied by 100 to show percentages
# Out:
# 1927    0.002687
# 1929    0.002687
# 1931    0.002687
# 1934    0.005375
# 1937    0.010749
# 1938    0.002687
# 1939    0.002687
# 1941    0.005375
# 1943    0.002687
# 1948    0.002687
# 1950    0.002687
# 1951    0.005375
# 1952    0.002687
# 1953    0.002687
# 1954    0.005375
# 1955    0.005375
# 1956    0.010749
# 1957    0.005375
# 1958    0.008062
# 1959    0.016124
# 1960    0.045684
# 1961    0.016124
# 1962    0.010749
# 1963    0.021498
# 1964    0.024186
# 1965    0.045684
# 1966    0.056433
# 1967    0.067183
# 1968    0.069870
# 1969    0.048371
#           ...
# 1987    0.137053
# 1988    0.284854
# 1989    0.330539
# 1990    0.507901
# 1991    0.556272
# 1992    0.588520
# 1993    0.585833
# 1994    0.728260
# 1995    1.190476
# 1996    1.456519
# 1997    2.114909
# 1998    3.447813
# 1999    4.635601
# 2000    5.377298
# 2001    5.549285
# 2002    5.737397
# 2003    6.656455
# 2004    7.008492
# 2005    7.484145
# 2006    7.126733
# 2007    6.070622
# 2008    5.922821
# 2009    5.581533
# 2010    4.256691
# 2011    4.345372
# 2012    3.509621
# 2013    2.136408
# 2014    1.744061
# 2015    0.970117
# 2016    1.749436
# Name: registration_year, Length: 77, dtype: float64

# %% [markdown]
# We can observe that from 1927 to 1994 very few cars were registered but after 1994 till 2007 there is a rapid increase in the number of cars registered again after 2007 there is gradual decrease till 2016.

# %%
autos['brand'].unique()
# Out:
# array(['peugeot', 'bmw', 'volkswagen', 'smart', 'ford', 'chrysler',
#        'audi', 'renault', 'sonstige_autos', 'mazda', 'porsche', 'mini',
#        'mercedes_benz', 'seat', 'toyota', 'opel', 'dacia', 'jeep', 'saab',
#        'volvo', 'nissan', 'jaguar', 'skoda', 'subaru', 'fiat',
#        'mitsubishi', 'chevrolet', 'hyundai', 'honda', 'kia', 'citroen',
#        'suzuki', 'trabant', 'land_rover', 'alfa_romeo', 'rover',
#        'daihatsu', 'daewoo', 'lancia', 'lada'], dtype=object)

# %%
brands = ((autos['brand'].value_counts(normalize=True))*100).head(6)

# %%
brands
# Out:
# volkswagen       21.081909
# bmw              12.536279
# mercedes_benz    11.157691
# audi              9.757605
# opel              8.905729
# ford              5.871762
# Name: brand, dtype: float64

# %%
popularity = brands

# %%
brands = brands.index

# %%
brands
# Out:
# Index(['volkswagen', 'bmw', 'mercedes_benz', 'audi', 'opel', 'ford'], dtype='object')

# %%
brand_mean_prices = {}
for brand in brands:
    mean_price = autos.loc[autos['brand']==brand, 'price'].mean()
    brand_mean_prices[brand] = mean_price

# %%
brand_mean_prices
# Out:
# {'audi': 10322.269347287249,
#  'bmw': 9381.89174705252,
#  'ford': 5786.703432494279,
#  'mercedes_benz': 9302.614402697494,
#  'opel': 4219.954737477368,
#  'volkswagen': 6898.376545570427}

# %% [markdown]
# * Despite having only ~9% share audi's are much more expensive thus suitable for rich, that also explains the smaller share.
# * Volkswagen has the majority share (ie- ~21%) and are moderately priced thus making them suitable for middle class families, that explains the large share.

# %%
brands
# Out:
# Index(['volkswagen', 'bmw', 'mercedes_benz', 'audi', 'opel', 'ford'], dtype='object')

# %%
brand_mean_mil = {}
for brand in brands:
    mean_mil = autos.loc[autos['brand'] == brand, 'odometer_km'].mean()
    brand_mean_mil[brand] = mean_mil

# %%
brand_mean_mil
# Out:
# {'audi': 127491.04929771413,
#  'bmw': 132005.359056806,
#  'ford': 119622.42562929062,
#  'mercedes_benz': 130062.6204238921,
#  'opel': 123952.92697646348,
#  'volkswagen': 125771.82919056724}

# %% [markdown]
# Making a new dataframe for further analysis on brands.

# %%
bmp_series = pd.Series(brand_mean_prices)

# %%
bmm_series = pd.Series(brand_mean_mil)

# %%
pop_series = pd.Series(popularity)

# %%
brands_mean = pd.DataFrame(bmp_series, columns=['mean_price'])

# %%
brands_mean['mean_milage'] = bmm_series

# %%
brands_mean['popularity'] = pop_series

# %%
brands_mean
# Out:
#                  mean_price    mean_milage  popularity
# audi           10322.269347  127491.049298    9.757605
# bmw             9381.891747  132005.359057   12.536279
# ford            5786.703432  119622.425629    5.871762
# mercedes_benz   9302.614403  130062.620424   11.157691
# opel            4219.954737  123952.926976    8.905729
# volkswagen      6898.376546  125771.829191   21.081909

# %% [markdown]
# ### Conclusions
# * Ford had the worst milage and was priced more than the competetors thus was not very popular.
# * BMW and mercedes_benz gave the best milage and therefore are quite expensive, but still were very popular.
# * Volkswagen gave a balance between cost and milage.
# * In general cars with higher milage were much more expensive that the cheaper ones.
#
# *** Milage here means the distance that was travelled by the car in it's service time period, the cars with more milage meant that they were more satisfactory to the owner thus used for longer period before selling. ***

# %% [markdown]
# # Extras

# %% [markdown]
# * Further cleaning - converting the german words to english

# %%
autos['unrepaired_damage'] = autos['unrepaired_damage'].map({'nein':'No' , 'ja':'Yes'})

# %%
autos['unrepaired_damage'].unique()
# Out:
# array(['No', nan, 'Yes'], dtype=object)

# %%
autos['unrepaired_damage'].value_counts(dropna=False)
# Out:
# No     29707
# NaN     5184
# Yes     2321
# Name: unrepaired_damage, dtype: int64

# %%
del_index = autos[autos['unrepaired_damage'].isnull()].index

# %%
autos.drop(del_index, axis=0, inplace=True)

# %%
damage_values = autos['unrepaired_damage'].unique()

# %%
damage_values
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
damage_mean_price = {}
for damage_value in damage_values:
    mean_price = autos.loc[autos["unrepaired_damage"] == damage_value, "price"].mean()
    damage_mean_price[damage_value] = mean_price

# %%
damage_mean_price
# Out:
# {'No': 8274.669943111052, 'Yes': 4328.579922447221}

# %% [markdown]
# * It can be clearly seen that cars with no damage are almost **double** the value of cars with damage

# %%
autos['model'].value_counts(normalize=True)*100
# Out:
# golf                  7.896091
# andere                7.558513
# 3er                   6.397891
# passat                3.067130
# a4                    2.980324
# 5er                   2.906379
# c_klasse              2.896734
# astra                 2.764918
# polo                  2.629887
# e_klasse              2.398405
# corsa                 2.231224
# a6                    2.121914
# a3                    2.115484
# transporter           1.755401
# focus                 1.668596
# 1er                   1.530350
# fortwo                1.433899
# 2_reihe               1.430684
# a_klasse              1.263503
# fiesta                1.224923
# touran                1.150977
# zafira                1.044882
# 3_reihe               0.948431
# x_reihe               0.884131
# mondeo                0.868056
# octavia               0.842335
# clio                  0.842335
# vectra                0.832690
# cooper                0.832690
# twingo                0.813400
#                         ...
# gl                    0.032150
# kalos                 0.028935
# forester              0.028935
# mii                   0.025720
# range_rover           0.025720
# ypsilon               0.025720
# terios                0.022505
# 900                   0.019290
# exeo                  0.016075
# crossfire             0.016075
# range_rover_evoque    0.016075
# justy                 0.016075
# sirion                0.016075
# lodgy                 0.016075
# amarok                0.016075
# croma                 0.012860
# 9000                  0.012860
# 90                    0.009645
# v60                   0.009645
# nubira                0.009645
# delta                 0.006430
# move                  0.006430
# r19                   0.006430
# kappa                 0.006430
# rangerover            0.003215
# samara                0.003215
# b_max                 0.003215
# 145                   0.003215
# lanos                 0.003215
# 200                   0.003215
# Name: model, Length: 240, dtype: float64

# %%
autos.loc[autos['model'] == 'golf', 'brand'].value_counts()
# Out:
# volkswagen    2456
# Name: brand, dtype: int64

# %% [markdown]
# * The most common brand-model combination is **Volkswagen-Golf**.

# %%
autos['gearbox'].value_counts(dropna=False)
# Out:
# manuell      23313
# automatik     8065
# NaN            650
# Name: gearbox, dtype: int64

# %%
mapping_dic = {'manuell':'manual', 'automatik':'automatic'}

# %%
autos['gearbox'] = autos['gearbox'].map(mapping_dic)

# %%
autos['gearbox'].unique()
# Out:
# array(['manual', 'automatic', nan], dtype=object)

# %%
autos['gearbox'].value_counts(dropna=False)
# Out:
# manual       23313
# automatic     8065
# NaN            650
# Name: gearbox, dtype: int64

# %% [markdown]
# Translated few German words to English.
